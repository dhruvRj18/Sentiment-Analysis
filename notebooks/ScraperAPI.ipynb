# %%
import requests
import pandas as pd

# %%
twitter_data = []

# %%
payload = {
    
    'api_key':'',
    'query' : 'artificial intelligence',
    'num':'25'
}

response = requests.get(
 'https://api.scraperapi.com/structured/twitter/search',
    params = payload
)
data = response.json()

# %%
data
# Out:
# {'search_information': {'query_displayed': 'site:twitter.com "artificial intelligence"',
#   'total_results': 465000,
#   'time_taken_displayed': 0.46},
#  'organic_results': [{'position': 0,
#    'title': 'Artificial Intelligence: Terms marketers need to know',
#    'snippet': "A great resource for AI in the marketing realm is Paul Roetzer's Marketing Artificial Intelligence Institute (MAII) – unbeatable content for learning and seeing\xa0...",
#    'highlighs': ['Artificial Intelligence'],
#    'link': 'https://business.twitter.com/en/blog/artificial-intelligence-terms-marketers-need-to-know.html',
#    'displayed_link': 'https://business.twitter.com › blog › artificial-intelligen...'},
#   {'position': 1,
#    'title': 'The pros and cons of AI in marketing - Twitter for Business',
#    'snippet': 'Deep learning through Artificial Intelligence allows computers to more accurately identify user behavior and predict which segments are more likely to become\xa0...',
#    'highlighs': ['Artificial Intelligence'],
#    'link': 'https://business.twitter.com/en/blog/the-pros-cons-ai-in-marketing.html',
#    'displayed_link': 'https://business.twitter.com › blog › the-pros-cons-ai-i...'},
#   {'position': 2,
#    'title': 'Congressman Tom Kean',
#    'snippet': 'Artificial intelligence is progressing fast, and so are the companies behind its development. We are living in a highly advanced\xa0...',
#    'highlighs': ['Artificial intelligence'],
#    'link': 'https://twitter.com/CongressmanKean/status/1729538580333121942',
#    'displayed_link': 'https://twitter.com › CongressmanKean › status'},
#   {'position': 3,
#    'title': 'American Progress',
#    'snippet': 'Artificial intelligence (AI) technology needs to be navigated in safe and innovative ways ... Artificial intelligence (AI) technology needs to\xa0...',
#    'highlighs': ['Artificial intelligence', 'Artificial intelligence'],
#    'link': 'https://mobile.twitter.com/amprog/status/1729616658610753649',
#    'displayed_link': 'https://mobile.twitter.com › amprog › status'},
#   {'position': 4,
#    'title': 'Andrew Keen',
#    'snippet': 'This punchy clip reveals how artificial intelligence is tethered to the past, while the human thought is intertwined with the future!',
#    'highlighs': ['artificial intelligence'],
#    'link': 'https://mobile.twitter.com/ajkeen/status/1729123166880960784',
#    'displayed_link': 'https://mobile.twitter.com › ajkeen › status'},
#   {'position': 5,
#    'title': 'Nathan Benaich',
#    'snippet': '"The idea that artificial intelligence could lead to the extinction of humanity is a lie being promulgated by big tech in the hope of\xa0...',
#    'highlighs': ['artificial intelligence'],
#    'link': 'https://twitter.com/nathanbenaich/status/1719086542604419543',
#    'displayed_link': 'https://twitter.com › nathanbenaich › status'},
#   {'position': 6,
#    'title': 'Rep. Seth Moulton',
#    'snippet': 'The national security threat of artificial intelligence is unprecedented. Left unchecked, AI could become more dangerous than the atomic bomb.',
#    'highlighs': ['artificial intelligence'],
#    'link': 'https://mobile.twitter.com/RepMoulton/status/1719363176905515062',
#    'displayed_link': 'https://mobile.twitter.com › RepMoulton › status'},
#   {'position': 7,
#    'title': 'Senator Mike Rounds',
#    'snippet': "Artificial Intelligence is here, and it's not going away. America must stay at the forefront of its development. Great to sit down with.",
#    'highlighs': ['Artificial Intelligence'],
#    'link': 'https://mobile.twitter.com/SenatorRounds/status/1716481791018549586',
#    'displayed_link': 'https://mobile.twitter.com › SenatorRounds › status'},
#   {'position': 8,
#    'title': 'Rep. Jay Obernolte',
#    'snippet': "Continued U.S. leadership in Artificial Intelligence is key to securing our country's economic and national security.",
#    'highlighs': ['Artificial Intelligence'],
#    'link': 'https://mobile.twitter.com/JayObernolte/status/1726439622241112409',
#    'displayed_link': 'https://mobile.twitter.com › JayObernolte › status'},
#   {'position': 9,
#    'title': 'Raúl Carrillo',
#    'snippet': "It's been a few months, and artificial intelligence persists, so I am once again asking the People of X for good work surveying the political\xa0...",
#    'highlighs': ['artificial intelligence'],
#    'link': 'https://twitter.com/RaulACarrillo/status/1729585737970975167',
#    'displayed_link': 'https://twitter.com › RaulACarrillo › status'},
#   {'position': 10,
#    'title': 'The Governing Board',
#    'snippet': 'The rapid ascendance of artificial intelligence is raising fundamental questions about what future students should be taught about\xa0...',
#    'highlighs': ['artificial intelligence'],
#    'link': 'https://twitter.com/GovBoard/status/1729158717923623346',
#    'displayed_link': 'https://twitter.com › GovBoard › status'},
#   {'position': 11,
#    'title': 'carlhonore',
#    'snippet': 'Artificial intelligence is ushering in a new epoch of speed. To understand AI, and point it in the right direction, we humans need to slow\xa0...',
#    'highlighs': ['Artificial intelligence'],
#    'link': 'https://twitter.com/carlhonore/status/1725205943816765697',
#    'displayed_link': 'https://twitter.com › carlhonore › status'},
#   {'position': 12,
#    'title': 'Rep. Frank Pallone',
#    'snippet': 'Artificial intelligence is not new, but the speed of its deployment is staggering. Many of these systems are trained on massive amounts of\xa0...',
#    'highlighs': ['Artificial intelligence'],
#    'link': 'https://mobile.twitter.com/FrankPallone/status/1714699406790869120',
#    'displayed_link': 'https://mobile.twitter.com › FrankPallone › status'},
#   {'position': 13,
#    'title': 'AARP',
#    'snippet': 'The use of artificial intelligence continues to be debated, especially when it comes to the classroom. Here are ways grownups can explore AI\xa0...',
#    'highlighs': ['artificial intelligence'],
#    'link': 'https://mobile.twitter.com/AARP/status/1726727873917006244',
#    'displayed_link': 'https://mobile.twitter.com › AARP › status'},
#   {'position': 14,
#    'title': 'ALA Conferences',
#    'snippet': "Artificial intelligence (AI) is changing the world, and libraries are at the forefront of this revolution. At #LibLearnX24, you'll learn All\xa0...",
#    'highlighs': ['Artificial intelligence'],
#    'link': 'https://twitter.com/ALAConferences/status/1725258211756741084',
#    'displayed_link': 'https://twitter.com › ALAConferences › status'},
#   {'position': 15,
#    'title': 'City & State Events',
#    'snippet': 'Artificial intelligence is altering how state and local governments operate. Join us on 12/12 as we explore challenges & opportunities for\xa0...',
#    'highlighs': ['Artificial intelligence'],
#    'link': 'https://mobile.twitter.com/CSNY_Events/status/1730388263179858197',
#    'displayed_link': 'https://mobile.twitter.com › CSNY_Events › status'},
#   {'position': 16,
#    'title': 'Atlantic Council',
#    'snippet': "NEW | What is artificial intelligence (AI), and how does it work? Watch. @JMU. 's Philip L. Frana (. @ArtificialOther. ) break down the inner\xa0...",
#    'highlighs': ['artificial intelligence'],
#    'link': 'https://mobile.twitter.com/AtlanticCouncil/status/1715416153378484627',
#    'displayed_link': 'https://mobile.twitter.com › AtlanticCouncil › status'},
#   {'position': 17,
#    'title': 'Rep. Seth Moulton',
#    'snippet': "Artificial Intelligence is the biggest technological threat we've faced since the invention of the atomic bomb. I am proud to be a part of\xa0...",
#    'highlighs': ['Artificial Intelligence'],
#    'link': 'https://twitter.com/RepMoulton/status/1691478756693520384?ref_src=twsrc%5Etfw',
#    'displayed_link': 'https://twitter.com › RepMoulton › status'},
#   {'position': 18,
#    'title': 'Max Roser',
#    'snippet': 'Why does powerful Artificial Intelligence pose a risk that could make all of our lives much, much worse in the coming years? There are many\xa0...',
#    'highlighs': ['Artificial Intelligence'],
#    'link': 'https://twitter.com/MaxCRoser/status/1651598037679063040',
#    'displayed_link': 'https://twitter.com › MaxCRoser › status'},
#   {'position': 19,
#    'title': 'AskEARN.org',
#    'snippet': "Did you know artificial intelligence (AI) can improve your organization's diversity, equity, inclusion, and accessibility efforts?",
#    'highlighs': ['artificial intelligence'],
#    'link': 'https://twitter.com/AskEARN/status/1724083949750882668',
#    'displayed_link': 'https://twitter.com › AskEARN › status'},
#   {'position': 20,
#    'title': 'United States Artificial Intelligence Institute (@usaiinstitute) ...',
#    'snippet': '... Artificial Intelligence Consultant (CAIC™). No programming experience required. Apply now and become a certified AI expert https://bit.ly/3L6L3do #USAII #AI\xa0...',
#    'highlighs': ['Artificial Intelligence'],
#    'link': 'https://twitter.com/usaiinstitute',
#    'displayed_link': 'https://twitter.com › usaiinstitute'},
#   {'position': 21,
#    'title': 'National Academies',
#    'snippet': 'Artificial intelligence has the potential to advance scientific discovery and reshape the way that research is conducted — join our\xa0...',
#    'highlighs': ['Artificial intelligence'],
#    'link': 'https://mobile.twitter.com/theNASEM/status/1711456612571853001',
#    'displayed_link': 'https://mobile.twitter.com › theNASEM › status'},
#   {'position': 22,
#    'title': 'Aaron Hertzmann',
#    'snippet': 'The problem is the name "Artificial Intelligence." It\'s just software. ... Our leaders are using the best and most rigorous science about AI to\xa0...',
#    'highlighs': ['Artificial Intelligence'],
#    'link': 'https://mobile.twitter.com/AaronHertzmann/status/1719455782213939535',
#    'displayed_link': 'https://mobile.twitter.com › AaronHertzmann › status'},
#   {'position': 23,
#    'title': 'Office for Artificial Intelligence (@OfficeforAI) ...',
#    'snippet': "Office for Artificial Intelligence's posts ; 3. 22. 27 ; 1. 8. 9 ; 16. 47. 65 ; 85. 191. 1K ; 56. 99. 158.",
#    'highlighs': ["Artificial Intelligence's"],
#    'link': 'https://twitter.com/OfficeforAI',
#    'displayed_link': 'https://twitter.com › OfficeforAI'}],
#  'pagination': {'load_more_url': 'http://api.scraperapi.com/?url=https%3A%2F%2Fwww.google.com%2Fsearch%3Fq%3Dsite%3Atwitter.com%2B%2522artificial%2Bintelligence%2522%26num%3D25%26sca_esv%3D587798794%26gl%3DUS%26ei%3Dpz5uZe2gF_qk1e8P7-eH4A0%26start%3D25%26sa%3DN&autoparse=true',
#   'pages_count': 1}}

# %%
data.keys()
# Out:
# dict_keys(['search_information', 'organic_results', 'pagination'])
