# %%
from transformers import pipeline

# Load the sentiment analysis model
sentiment_analyzer = pipeline("sentiment-analysis", model="nlptown/bert-base-multilingual-uncased-sentiment")

# Read captions from the text file
input_file_path = "../data/top_100_captions.txt"
with open(input_file_path, "r", encoding="utf-8") as input_file:
    captions = input_file.readlines()

# Annotate the dataset with sentiment labels
annotated_dataset = []

for caption in captions:
    # Use the sentiment analysis model to get the sentiment label
    result = sentiment_analyzer(caption)[0]
    sentiment_label = result['label']
    
    # Map the sentiment label to 'positive', 'negative', or 'neutral'
    if sentiment_label == 'POSITIVE':
        sentiment = 'positive'
    elif sentiment_label == 'NEGATIVE':
        sentiment = 'negative'
    else:
        sentiment = 'neutral'
    
    # Add the annotated data to the dataset
    annotated_dataset.append({
        'caption': caption,  # Remove leading/trailing whitespaces
        'sentiment': sentiment
    })

# Print or further process the annotated dataset
for entry in annotated_dataset:
    print(f"Caption: {entry['caption']}, Sentiment: {entry['sentiment']}")
# Out:
# Caption: #EndTheGenocide #AccountabilityNow #uselection #voteforchange
# , Sentiment: neutral
# Caption: #viral #reels#reelsindia #reelsinstagram#viralvideos #viral #india #🙏🏻 #instabook #lifecoach #artist
# , Sentiment: neutral
# Caption: #virale #viralfood #teepee #newsongs #homealone2 #uselection #musically🎶 #🙏🏻❤️ #kedarnath_dham🙏🙏♥️♥️ #humanmade #modelmaking
# , Sentiment: neutral
# Caption: #simplepost #viewpointperspective #sareemodels #virushkareception #basketmaking #danceinstructors #jemezmountains #quotesofthenight
# , Sentiment: neutral
# Caption: Write a caption... #viral #reels#reelsindia #reelsinstagram#viralvideos #viral #india #🙏🏻 #instabook #lifecoach #artist
# , Sentiment: neutral
# Caption: #virale #viralfood #teepee #newsongs #homealone2 #uselection #musically🎶 #🙏🏻❤️ #kedarnath_dham🙏🙏♥️♥️ #humanmade #modelmaking
# , Sentiment: neutral
# ...
